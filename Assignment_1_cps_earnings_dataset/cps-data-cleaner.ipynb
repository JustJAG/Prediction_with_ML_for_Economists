# %%
####################################################################
# Prepared for Gabor's Data Analysis
#
# Data Analysis for Business, Economics, and Policy
# by Gabor Bekes and  Gabor Kezdi
# Cambridge University Press 2021
#
# gabors-data-analysis.com
#
# License: Free to share, modify and use for educational purposes.
# 	Not to be used for commercial purposes.
#
####################################################################

####################################################################
# cps-earnings dataset
#
# input:
#       morg2014.csv

# output:
#       morg-2014-emp.csv

# version 1.0   2021-05-23
####################################################################

# %%
### SETTING UP DIRECTORIES

# import packages
import pandas as pd
import os
import numpy as np

# set working directory for da_data_repo -- replace the
os.chdir('C:\\Users\\77774\\Documents\\GitHub\\Prediction_with_ML_for_Economists\\Assignment_1_cps_earnings_dataset')

# location folders
data_in = "C:\\Users\\77774\\Documents\\GitHub\\Prediction_with_ML_for_Economists\\Assignment_1_cps_earnings_dataset\\raw\\"
data_out = "C:\\Users\\77774\\Documents\\GitHub\\Prediction_with_ML_for_Economists\\Assignment_1_cps_earnings_dataset\\clean\\"

# %%
# load dataset (as unicode, to avoid size and memor warnings)

df = pd.read_csv(
    data_in + "morg2014.csv",
    quotechar='"',
    delimiter=",",
    encoding="utf-8",
    dtype = "unicode"
)

# %%
# select a subset of columns
df= df[
    [
        "lfsr94", #employment status
        "hhid", #household id
        "lineno", #
        "intmonth", #int_month
        "stfips", #state
        "weight",
        "earnwke", #weakly earnings
        "uhourse", #usual work hours
        "grade92", #highest educ
        "race", #race
        "ethnic", #ethnicity
        "age", #age
        "sex", #gender
        "marital",
        "ownchild",
        "chldpres",
        "prcitshp",
        "state",
        "ind02",
        "occ2012", #occupational code
        "class94",
        "unionmme",
        "unioncov",
    ]
]

# %%
# rename variables

df.reset_index(drop=True,inplace=True)
df.rename(
    columns={
        "class94": "class",
        "uhourse": "uhours",
    },
    inplace=True,
)

# %%
# destring filter variables

df["age"] = pd.to_numeric(df["age"], errors="coerce").astype("Int64")

df["earnwke"] = pd.to_numeric(df["earnwke"], errors="coerce")
df["earnwke"] = df.earnwke.fillna(0)

df["uhours"] = pd.to_numeric(df["uhours"], errors="coerce").astype("Int64")
df["uhours"] = df.uhours.fillna(0)

# %%
# filtering dataset

df = df[(df.age >= 16) & (df.age <= 64)]

df = df[(df.lfsr94 == "Employed-At Work") | (df.lfsr94 == "Employed-Absent")]

df.drop(df.loc[(df.earnwke == 0) | (df.uhours == 0)].index, inplace=True)

df.reset_index(drop=True, inplace=True)

# %%
# save table

df.to_csv(data_out + "morg-2014-emp.csv", index=False)

# %%
df.describe()
# Out:
#              earnwke         uhours            age
# count  149316.000000  149316.000000  149316.000000
# mean      888.834343      38.939819      40.706810
# std       643.737322      10.259280      12.776095
# min         0.010000       1.000000      16.000000
# 25%       430.000000      40.000000      30.000000
# 50%       719.600000      40.000000      41.000000
# 75%      1153.840000      40.000000      52.000000
# max      2884.610000      99.000000      64.000000

# %%
df
# Out:
#                   lfsr94             hhid lineno  intmonth stfips     weight  \
# 0       Employed-At Work  002600310997690      3   January     AL  3151.6801
# 1        Employed-Absent  075680310997590      1   January     AL  3457.1138
# 2       Employed-At Work  075680310997590      2   January     AL   3936.911
# 3       Employed-At Work  179140131100930      1   January     AL   3288.364
# 4       Employed-At Work  179140131100930      2   January     AL    3422.85
# ...                  ...              ...    ...       ...    ...        ...
# 149311  Employed-At Work  896679860459501      2  December     WY   346.2296
# 149312  Employed-At Work  907086820569600      1  December     WY     294.98
# 149313  Employed-At Work  907086820569600      2  December     WY   324.1761
# 149314  Employed-At Work  950868097156649      1  December     WY   321.6982
# 149315  Employed-At Work  950868097156649      2  December     WY     294.98
#
#         earnwke  uhours grade92 race  ... marital  ownchild chldpres  \
# 0       1692.00      40      43    1  ...       7         0        0
# 1        450.00      40      41    2  ...       1         2        6
# 2       1090.00      60      41    2  ...       1         2        6
# 3        769.23      40      40    1  ...       1         2        4
# 4        826.92      40      43    1  ...       1         2        4
# ...         ...     ...     ...  ...  ...     ...       ...      ...
# 149311   692.30      40      39    1  ...       6         0        0
# 149312  1984.61      40      44    1  ...       1         1        3
# 149313  2884.61      55      43    1  ...       1         1        3
# 149314  1153.84      40      42    1  ...       1         0        0
# 149315   673.07      40      40    1  ...       1         0        0
#
#                   prcitshp state  \
# 0       Native, Born In US    63
# 1       Native, Born In US    63
# 2       Native, Born In US    63
# 3       Native, Born In US    63
# 4       Native, Born In US    63
# ...                    ...   ...
# 149311  Native, Born In US     8
# 149312  Native, Born In US     8
# 149313  Native, Born In US     8
# 149314  Native, Born In US     8
# 149315  Native, Born In US     8
#
#                                                     ind02 occ2012  \
# 0                              Employment services (5613)     630
# 1                          Outpatient care centers (6214)    5400
# 2       Motor vehicles and motor vehicle equipment man...    8140
# 3       **Publishing, except newspapers and software (...    8255
# 4       Banking and related activities (521, 52211,52219)    5940
# ...                                                   ...     ...
# 149311      Office supplies and stationery stores (45321)    4760
# 149312    Administration of human resource programs (923)     430
# 149313                     Nursing care facilities (6231)      10
# 149314                                    Hospitals (622)    5820
# 149315                 Pharmacies and drug stores (44611)    3420
#
#                       class unionmme unioncov
# 0       Private, For Profit       No       No
# 1       Private, For Profit       No       No
# 2       Private, For Profit       No       No
# 3       Private, For Profit      Yes      NaN
# 4       Private, For Profit       No       No
# ...                     ...      ...      ...
# 149311  Private, For Profit       No       No
# 149312   Government - State       No       No
# 149313  Private, For Profit       No       No
# 149314   Private, Nonprofit       No       No
# 149315  Private, For Profit       No       No
#
# [149316 rows x 23 columns]
